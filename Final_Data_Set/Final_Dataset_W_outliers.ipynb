# %%
# !pip install xlsxwriter
# !pip install imbalanced-learn
# !pip install category_encoders
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\joyce\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: imbalanced-learn in c:\users\joyce\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\joyce\anaconda3\lib\site-packages (from imbalanced-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\joyce\anaconda3\lib\site-packages (from imbalanced-learn) (1.12.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\joyce\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\joyce\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\joyce\anaconda3\lib\site-packages (from imbalanced-learn) (3.2.0)
# Requirement already satisfied: category_encoders in c:\users\joyce\anaconda3\lib\site-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\joyce\anaconda3\lib\site-packages (from category_encoders) (1.26.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\joyce\anaconda3\lib\site-packages (from category_encoders) (1.4.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\joyce\anaconda3\lib\site-packages (from category_encoders) (1.12.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\joyce\anaconda3\lib\site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\joyce\anaconda3\lib\site-packages (from category_encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\joyce\anaconda3\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joyce\appdata\roaming\python\python311\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joyce\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\joyce\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.4)
# Requirement already satisfied: six in c:\users\joyce\appdata\roaming\python\python311\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joyce\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\joyce\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\joyce\appdata\roaming\python\python311\site-packages (from statsmodels>=0.9.0->category_encoders) (23.2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from category_encoders import WOEEncoder
import category_encoders as ce

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.utils import resample
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB


from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../diabetes_prediction_dataset.csv')

df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
#checking empty rows in the dataframe
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# Checking Unique Variables in Gender Column
unique_gender_initial = df['gender'].unique()
print(unique_gender_initial)
# Out:
# ['Female' 'Male' 'Other']

# %%
# Remove 'Other' from column
df = df[df['gender'] != 'Other']

# %%
# Checking Unique Variables in Gender Column after removal of 'other'
unique_gender_new= df['gender'].unique()
print(unique_gender_new)
# Out:
# ['Female' 'Male']

# %%
# Checking Unique Variables in smoking_history Column
unique_smoking_history_initial = df['smoking_history'].unique()
print(unique_smoking_history_initial)
# Out:
# ['never' 'No Info' 'current' 'former' 'ever' 'not current']

# %%
#checking for NaN values in smoking_history Column
nan_values = df['smoking_history'].isna().sum()

nan_values
# Out:
# 0

# %%
df['smoking_history'].isnull().sum()
# Out:
# 0

# %% [markdown]
# We have categorized “never” , “No info” as “no”, “current”, “former”, “ever” and “not current” have been categorized as “yes”.

# %%
new_values = {"never": "no", "No Info":"no", "current": "yes",  "former": "yes", "ever": "yes", "not current": "yes", }
df['smoking_history'] = df['smoking_history'].map(new_values)

# %%
unique_smoking_history_new = df['smoking_history'].unique()

unique_smoking_history_new
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1              no  25.19
# 1      Female  54.0             0              0              no  27.32
# 2        Male  28.0             0              0              no  27.32
# 3      Female  36.0             0              0             yes  23.45
# 4        Male  76.0             1              1             yes  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0              no  27.32
# 99996  Female   2.0             0              0              no  17.37
# 99997    Male  66.0             0              0             yes  27.83
# 99998  Female  24.0             0              0              no  35.42
# 99999  Female  57.0             0              0             yes  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [99982 rows x 9 columns]

# %% [markdown]
# Encoding gender and smoking history using WOE Encoding

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from category_encoders import WOEEncoder
import category_encoders as ce

from sklearn.preprocessing import LabelEncoder

from sklearn.utils import resample
plt.style.use('ggplot')

# %% [markdown]
# Applying WOE Encoding for Smoking History

# %%
#applying WOE encoding for smoking history
# Applying WOE encoding for smoking history
woe_encoder_smoking_history = ce.WOEEncoder(cols=['smoking_history'])

# %%
# Fit and transform the encoder on the data
encoded_smoking_history_df = pd.DataFrame()

encoded_smoking_history_df['smoking_history_encoded'] = woe_encoder_smoking_history.fit_transform(df['smoking_history'], df['diabetes'])

# %%
# Concatenate the encoded data with the original DataFrame
df_with_outliers = pd.concat([df, encoded_smoking_history_df], axis=1)

# %%
df_with_outliers.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1              no  25.19
# 1  Female  54.0             0              0              no  27.32
# 2    Male  28.0             0              0              no  27.32
# 3  Female  36.0             0              0             yes  23.45
# 4    Male  76.0             1              1             yes  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes  smoking_history_encoded
# 0          6.6                  140         0                -0.246527
# 1          6.6                   80         0                -0.246527
# 2          5.7                  158         0                -0.246527
# 3          5.0                  155         0                 0.450465
# 4          4.8                  155         0                 0.450465

# %% [markdown]
# Applying WOE Encoding for Gender

# %%
#applying WOE encoding for gender
# Applying WOE encoding for gender
woe_encoder_gender_and_smoking = ce.WOEEncoder(cols=['gender'])

# %%
# Fit and transform the encoder on the data
encoded_smoking_history__gender_df = pd.DataFrame()

encoded_smoking_history__gender_df['gender_encoded'] = woe_encoder_gender_and_smoking.fit_transform(df_with_outliers['gender'], df_with_outliers['diabetes'])

# %%
# Concatenate the encoded data with the original DataFrame
df_with_outliers_encoded_gender_smoking = pd.concat([df_with_outliers,encoded_smoking_history__gender_df], axis=1)

# %%
df_with_outliers_encoded_gender_smoking
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1              no  25.19
# 1      Female  54.0             0              0              no  27.32
# 2        Male  28.0             0              0              no  27.32
# 3      Female  36.0             0              0             yes  23.45
# 4        Male  76.0             1              1             yes  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0              no  27.32
# 99996  Female   2.0             0              0              no  17.37
# 99997    Male  66.0             0              0             yes  27.83
# 99998  Female  24.0             0              0              no  35.42
# 99999  Female  57.0             0              0             yes  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes  smoking_history_encoded  \
# 0              6.6                  140         0                -0.246527
# 1              6.6                   80         0                -0.246527
# 2              5.7                  158         0                -0.246527
# 3              5.0                  155         0                 0.450465
# 4              4.8                  155         0                 0.450465
# ...            ...                  ...       ...                      ...
# 99995          6.2                   90         0                -0.246527
# 99996          6.5                  100         0                -0.246527
# 99997          5.7                  155         0                 0.450465
# 99998          4.0                  100         0                -0.246527
# 99999          6.6                   90         0                 0.450465
#
#        gender_encoded
# 0           -0.119227
# 1           -0.119227
# 2            0.150651
# 3           -0.119227
# 4            0.150651
# ...               ...
# 99995       -0.119227
# 99996       -0.119227
# 99997        0.150651
# 99998       -0.119227
# 99999       -0.119227
#
# [99982 rows x 11 columns]

# %%
columns_to_remove = ['gender','smoking_history']

# %%
# Make a copy of the DataFrame without the specified columns
df_for_normalization = df_with_outliers_encoded_gender_smoking.drop(columns_to_remove, axis=1).copy()

# %%
df_for_normalization
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  smoking_history_encoded  gender_encoded
# 0                      140         0                -0.246527       -0.119227
# 1                       80         0                -0.246527       -0.119227
# 2                      158         0                -0.246527        0.150651
# 3                      155         0                 0.450465       -0.119227
# 4                      155         0                 0.450465        0.150651
# ...                    ...       ...                      ...             ...
# 99995                   90         0                -0.246527       -0.119227
# 99996                  100         0                -0.246527       -0.119227
# 99997                  155         0                 0.450465        0.150651
# 99998                  100         0                -0.246527       -0.119227
# 99999                   90         0                 0.450465       -0.119227
#
# [99982 rows x 9 columns]

# %%
df_for_normalization.to_csv('Original Dataset with Outliers Included.csv', index=False)

# %% [markdown]
# Normalization of the above Dataset

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns for standardization
numerical_columns = ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'smoking_history_encoded', 'gender_encoded']

# Create a StandardScaler instance
scaler = StandardScaler()

df_for_normalization[numerical_columns] = scaler.fit_transform(df_for_normalization[numerical_columns])

df_for_normalization
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0      1.692577             0              1 -0.321051     1.001692
# 1      0.537899             0              0 -0.000114     1.001692
# 2     -0.616779             0              0 -0.000114     0.161089
# 3     -0.261494             0              0 -0.583225    -0.492714
# 4      1.514935             1              1 -1.081957    -0.679515
# ...         ...           ...            ...       ...          ...
# 99995  1.692577             0              0 -0.000114     0.628091
# 99996 -1.771458             0              0 -1.499326     0.908292
# 99997  1.070828             0              0  0.076730     0.161089
# 99998 -0.794422             0              0  1.220350    -1.426718
# 99999  0.671131             0              0 -0.736913     1.001692
#
#        blood_glucose_level  diabetes  smoking_history_encoded  gender_encoded
# 0                 0.047709         0                -0.640425       -0.841175
# 1                -1.426157         0                -0.640425       -0.841175
# 2                 0.489869         0                -0.640425        1.188813
# 3                 0.416175         0                 1.561464       -0.841175
# 4                 0.416175         0                 1.561464        1.188813
# ...                    ...       ...                      ...             ...
# 99995            -1.180513         0                -0.640425       -0.841175
# 99996            -0.934869         0                -0.640425       -0.841175
# 99997             0.416175         0                 1.561464        1.188813
# 99998            -0.934869         0                -0.640425       -0.841175
# 99999            -1.180513         0                 1.561464       -0.841175
#
# [99982 rows x 9 columns]

# %%
df_for_normalization.to_csv('Original Dataset with Outliers Included Normalized.csv', index=False)
