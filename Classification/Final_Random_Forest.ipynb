# %%
import pandas as pd

# %%
Outliers_Normalized=pd.read_csv('../Final_Data_Set/Original Dataset with Outliers Included Normalized.csv')

# %%
Outliers_Normalized
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0      1.692577             0              1 -0.321051     1.001692
# 1      0.537899             0              0 -0.000114     1.001692
# 2     -0.616779             0              0 -0.000114     0.161089
# 3     -0.261494             0              0 -0.583225    -0.492714
# 4      1.514935             1              1 -1.081957    -0.679515
# ...         ...           ...            ...       ...          ...
# 99977  1.692577             0              0 -0.000114     0.628091
# 99978 -1.771458             0              0 -1.499326     0.908292
# 99979  1.070828             0              0  0.076730     0.161089
# 99980 -0.794422             0              0  1.220350    -1.426718
# 99981  0.671131             0              0 -0.736913     1.001692
#
#        blood_glucose_level  diabetes  smoking_history_encoded  gender_encoded
# ...

# %%
Outliers_Non_Normalized=pd.read_csv('../Final_Data_Set/Original Dataset with Outliers Included.csv')

# %%
Outliers_Non_Normalized
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0      1.692577             0              1 -0.321051     1.001692
# 1      0.537899             0              0 -0.000114     1.001692
# 2     -0.616779             0              0 -0.000114     0.161089
# 3     -0.261494             0              0 -0.583225    -0.492714
# 4      1.514935             1              1 -1.081957    -0.679515
# ...         ...           ...            ...       ...          ...
# 99977  1.692577             0              0 -0.000114     0.628091
# 99978 -1.771458             0              0 -1.499326     0.908292
# 99979  1.070828             0              0  0.076730     0.161089
# 99980 -0.794422             0              0  1.220350    -1.426718
# 99981  0.671131             0              0 -0.736913     1.001692
#
#        blood_glucose_level  diabetes  smoking_history_encoded  gender_encoded
# ...

# %%
Without_Outliers_Normalized=pd.read_csv('../Final_Data_Set/Original Dataset without Outliers Normalized.csv')

# %%
Without_Outliers_Normalized
# Out:
#             age  hypertension  heart_disease       bmi  HbA1c_level  \
# 0      1.713008             0              1 -0.286437     1.134061
# 1      0.560337             0              0  0.072849     1.134061
# 2     -0.592335             0              0  0.072849     0.232946
# 3     -0.237667             0              0 -0.579938    -0.467921
# 4      1.535674             1              1 -1.138266    -0.668169
# ...         ...           ...            ...       ...          ...
# 96303  1.713008             0              0  0.072849     0.733566
# 96304 -1.745006             0              0 -1.605507     1.033937
# 96305  1.092339             0              0  0.158875     0.232946
# 96306 -0.769669             0              0  1.439149    -1.469161
# 96307  0.693337             0              0 -0.751991     1.134061
#
#        blood_glucose_level  diabetes  smoking_history_encoded  gender_encoded
# ...

# %%
Without_Outliers_Non_Normalized=pd.read_csv('../Final_Data_Set/Original Dataset without Outliers.csv')

# %%
Without_Outliers_Non_Normalized
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 96303  80.0             0              0  27.32          6.2
# 96304   2.0             0              0  17.37          6.5
# 96305  66.0             0              0  27.83          5.7
# 96306  24.0             0              0  35.42          4.0
# 96307  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  smoking_history_encoded  gender_encoded
# 0                      140         0                -0.247356       -0.128959
# ...
